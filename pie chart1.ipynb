# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('dataset.csv')
df
# Out:
#          country  gold_medal
# 0  United States          46
# 1  Great Britain          27
# 2          China          26
# 3         Russia          19
# 4        Germany          17

# %%
plt.pie(df['gold_medal'],labels=df['country'],autopct='%.2f%%',shadow=True)
plt.legend(df['country'])
plt.axis('equal')
plt.show()
